# %% [markdown]
# # CS235F24 Assignment 2
#
# **Dataset:** Airbnb

# %% [markdown]
# # Imports

# %%
# [INSERT CODE TO IMPORT NECESSARY PYTHON PACKAGES HERE]

import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # 0. Load Data / Data Exploration

# %%
trainDF = pd.read_csv('train.csv')
testDF = pd.read_csv('test.csv')
# Out:
# <ipython-input-28-205a7c7efff0>:1: DtypeWarning: Columns (30) have mixed types. Specify dtype option on import or set low_memory=False.
#   trainDF = pd.read_csv('train.csv')

# %%
# Get columns that are already numerical
numerical_columns = trainDF.select_dtypes(include=['number']).columns
print("Numerical Columns:\n", numerical_columns)
# Out:
# Numerical Columns:
#  Index(['id', 'host_id', 'host_acceptance_rate', 'host_listings_count',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'square_feet', 'price',
#        'guests_included', 'minimum_nights', 'maximum_nights',
#        'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'calculated_host_listings_count',
#        'reviews_per_month'],
#       dtype='object')

# %%
potentially_numerical = []

for col in trainDF.columns:
    try:
        pd.to_numeric(trainDF[col], errors='raise')
        potentially_numerical.append(col)
    except ValueError:
        continue

print("Columns that can be converted to numerical:\n", potentially_numerical)
# Out:
# Columns that can be converted to numerical:
#  ['id', 'host_id', 'host_acceptance_rate', 'host_listings_count', 'accommodates', 'bathrooms', 'bedrooms', 'beds', 'square_feet', 'price', 'guests_included', 'minimum_nights', 'maximum_nights', 'number_of_reviews', 'review_scores_rating', 'review_scores_accuracy', 'review_scores_cleanliness', 'review_scores_checkin', 'review_scores_communication', 'review_scores_location', 'review_scores_value', 'calculated_host_listings_count', 'reviews_per_month']

# %% [markdown]
# [INSERT WRITE-UP HERE. Explain any data quality issues that you observe and if you preformed any pre-processing]

# %% [markdown]
# # 1. Model Training (30 points)
#
# Train at least 3 models. You may test more than 3 models and apply your own cross-validation approach to choose the top three models to submit to Kaggle. You should include a section

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Reload the train dataset (in local environment, replace '/mnt/data/train.csv' with 'train.csv')


# Set 'price' as the target variable and identify numerical columns, excluding 'price'
target = trainDF['price']
numerical_columns = trainDF.select_dtypes(include=['number']).columns.drop('price')

# Fill NaN values in numerical columns for analysis
trainDF[numerical_columns] = trainDF[numerical_columns].fillna(0.001)

# Calculate correlations with 'price'
correlations = trainDF[numerical_columns].corrwith(target).sort_values(ascending=False)

# Plot the correlations with 'price'
plt.figure(figsize=(10, 8))
sns.barplot(x=correlations.values, y=correlations.index, palette="viridis")
plt.title("Correlation of Numerical Features with Price")
plt.xlabel("Correlation Coefficient")
plt.ylabel("Feature")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a6d4d15de283> in <cell line: 9>()
#       7
#       8 # Set 'price' as the target variable and identify numerical columns, excluding 'price'
# ----> 9 target = trainDF['price']
#      10 numerical_columns = trainDF.select_dtypes(include=['number']).columns.drop('price')
#      11
#
# NameError: name 'trainDF' is not defined

# %% [markdown]
# [INSERT WRITE-UP HERE]

# %%
# Model 2

# %%
# Model 3

# %% [markdown]
# [INSERT WRITE-UP HERE]

# %% [markdown]
# # 2. Plotting (10 points)

# %%
# [INSERT CODE HERE]

# %% [markdown]
# [INSERT WRITE-UP HERE]

# %% [markdown]
# # 3. Discussion (10 points)

# %% [markdown]
# Note, the rest of the points are based on Kaggle submission and ranking.

# %% [markdown]
# # References / Disclosure
#
# [List the sources you used to complete this assignment here]
